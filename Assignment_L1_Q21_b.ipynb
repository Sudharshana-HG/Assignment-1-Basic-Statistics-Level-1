# %% [markdown]
# <a href="https://colab.research.google.com/github/Sudharshana-HG/Assignment-1-Basic-Statistics-Level-1/blob/main/Assignment_L1_Q21_b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/wc-at.csv')

# %%
data
# Out:
#       Waist      AT
# 0     74.75   25.72
# 1     72.60   25.89
# 2     81.80   42.60
# 3     83.95   42.80
# 4     74.65   29.84
# ..      ...     ...
# 104  100.10  124.00
# 105   93.30   62.20
# 106  101.80  133.00
# 107  107.90  208.00
# 108  108.50  208.00
#
# [109 rows x 2 columns]

# %%
# plotting distribution for Waist Circumference (Waist) 
sns.distplot(data['Waist']);
# Out:
# <ipython-input-26-9ba96bbd6a59>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Waist']);

# %%
# plotting distribution for Adipose Tissue (AT) 
sns.distplot(data.AT)
plt.ylabel('Density')
plt.show()
# Out:
# <ipython-input-18-659081818e8f>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.AT)

# %%
data.boxplot()
# Out:
# <Axes: >

# %%
#Waist
data['Waist'].mean()  , data['Waist'].median()
# Out:
# (91.90183486238531, 90.8)

# %%
#AT
data['AT'].mean()  ,   data['AT'].median()
# Out:
# (101.89403669724771, 96.54)

# %%
data.plot.scatter(x='Waist', y='AT', title='Scatterplot')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: title={'center': 'Scatterplot'}, xlabel='Waist', ylabel='AT'>
